# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of 2000 random latitudes and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=29aa51b70ba15478a19ac938827a780d

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "yellowknife"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -114.3525, 'lat': 62.456},
#  'weather': [{'id': 520,
#    'main': 'Rain',
#    'description': 'light intensity shower rain',
#    'icon': '09d'}],
#  'base': 'stations',
#  'main': {'temp': 57.72,
#   'feels_like': 57.06,
#   'temp_min': 57.72,
#   'temp_max': 57.72,
#   'pressure': 1017,
#   'humidity': 82},
#  'visibility': 10000,
#  'wind': {'speed': 6.91, 'deg': 260},
#  'clouds': {'all': 100},
#  'dt': 1659228189,
#  'sys': {'type': 1,
#   'id': 1007,
#   'country': 'CA',
#   'sunrise': 1659178481,
#   'sunset': 1659241968},
#  'timezone': -21600,
#  'id': 6185377,
#  'name': 'Yellowknife',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | monrovia
# Processing Record 2 of Set 1 | lompoc
# Processing Record 3 of Set 1 | kuvshinovo
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | mayo
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | beringovskiy
# Processing Record 12 of Set 1 | fort nelson
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 16 of Set 1 | wanderlandia
# City not found. Skipping...
# Processing Record 17 of Set 1 | iracoubo
# Processing Record 18 of Set 1 | santiago de cao
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | pitimbu
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | amazar
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | anadyr
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | fare
# Processing Record 30 of Set 1 | coahuayana
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | colotlan
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | san cristobal
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | lagoa
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | dianopolis
# City not found. Skipping...
# Processing Record 41 of Set 1 | matagami
# Processing Record 42 of Set 1 | alcudia
# Processing Record 43 of Set 1 | ponta do sol
# Processing Record 44 of Set 1 | trelew
# Processing Record 45 of Set 1 | kavaratti
# Processing Record 46 of Set 1 | mount gambier
# Processing Record 47 of Set 1 | college
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | marzuq
# Processing Record 50 of Set 1 | adamovka
# Processing Record 1 of Set 2 | turayf
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | rovaniemi
# Processing Record 7 of Set 2 | provideniya
# Processing Record 8 of Set 2 | adrar
# Processing Record 9 of Set 2 | andenes
# Processing Record 10 of Set 2 | paungde
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | omboue
# Processing Record 13 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 2 | bull savanna
# Processing Record 15 of Set 2 | san antonio del monte
# Processing Record 16 of Set 2 | rio cuarto
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | sobolevo
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | durant
# Processing Record 21 of Set 2 | san matias
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | madingou
# Processing Record 25 of Set 2 | loknya
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 2 | buraydah
# Processing Record 29 of Set 2 | los llanos de aridane
# Processing Record 30 of Set 2 | biak
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | port-gentil
# Processing Record 35 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 2 | buala
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | victoria
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | ahipara
# Processing Record 42 of Set 2 | carmo do rio claro
# Processing Record 43 of Set 2 | bad wildungen
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | zhoucheng
# Processing Record 47 of Set 2 | plettenberg bay
# Processing Record 48 of Set 2 | ishigaki
# Processing Record 49 of Set 2 | acapulco
# Processing Record 50 of Set 2 | naze
# Processing Record 1 of Set 3 | sibolga
# Processing Record 2 of Set 3 | uvalde
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | muzhi
# Processing Record 5 of Set 3 | marawi
# Processing Record 6 of Set 3 | vardo
# Processing Record 7 of Set 3 | tecoanapa
# Processing Record 8 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 3 | cockburn town
# City not found. Skipping...
# Processing Record 10 of Set 3 | blagoyevo
# Processing Record 11 of Set 3 | qui nhon
# Processing Record 12 of Set 3 | imeni morozova
# Processing Record 13 of Set 3 | kalino
# Processing Record 14 of Set 3 | grindavik
# Processing Record 15 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 3 | nizhnyaya poyma
# Processing Record 17 of Set 3 | saint-georges
# Processing Record 18 of Set 3 | tasiilaq
# Processing Record 19 of Set 3 | goderich
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | itigi
# Processing Record 22 of Set 3 | tuatapere
# Processing Record 23 of Set 3 | stornoway
# Processing Record 24 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | esperance
# Processing Record 27 of Set 3 | henties bay
# Processing Record 28 of Set 3 | valparaiso
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | noumea
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | jamestown
# Processing Record 33 of Set 3 | bambous virieux
# Processing Record 34 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 35 of Set 3 | nouadhibou
# Processing Record 36 of Set 3 | maldonado
# Processing Record 37 of Set 3 | lasa
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | ngunguru
# City not found. Skipping...
# Processing Record 40 of Set 3 | aklavik
# Processing Record 41 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 3 | vostok
# Processing Record 43 of Set 3 | sistranda
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | upernavik
# Processing Record 46 of Set 3 | afgoye
# City not found. Skipping...
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | prestea
# Processing Record 49 of Set 3 | fortuna
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | chambas
# Processing Record 2 of Set 4 | barcelos
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | yulara
# Processing Record 5 of Set 4 | truro
# Processing Record 6 of Set 4 | berdigestyakh
# Processing Record 7 of Set 4 | severo-kurilsk
# Processing Record 8 of Set 4 | yellowknife
# Processing Record 9 of Set 4 | dunedin
# Processing Record 10 of Set 4 | merrillville
# Processing Record 11 of Set 4 | saint-pierre
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 16 of Set 4 | bosaso
# Processing Record 17 of Set 4 | contamana
# Processing Record 18 of Set 4 | waingapu
# Processing Record 19 of Set 4 | talara
# Processing Record 20 of Set 4 | myre
# Processing Record 21 of Set 4 | markova
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | batticaloa
# Processing Record 24 of Set 4 | seoul
# Processing Record 25 of Set 4 | pangody
# Processing Record 26 of Set 4 | severnoye
# Processing Record 27 of Set 4 | finnsnes
# Processing Record 28 of Set 4 | salinopolis
# Processing Record 29 of Set 4 | kieta
# Processing Record 30 of Set 4 | ostrovnoy
# Processing Record 31 of Set 4 | longyan
# Processing Record 32 of Set 4 | east london
# Processing Record 33 of Set 4 | mogadishu
# Processing Record 34 of Set 4 | sorong
# Processing Record 35 of Set 4 | xuddur
# Processing Record 36 of Set 4 | isla vista
# Processing Record 37 of Set 4 | bengkulu
# Processing Record 38 of Set 4 | vitim
# Processing Record 39 of Set 4 | huangzhai
# Processing Record 40 of Set 4 | morros
# Processing Record 41 of Set 4 | ponta delgada
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | sakakah
# Processing Record 44 of Set 4 | cayenne
# Processing Record 45 of Set 4 | tukrah
# Processing Record 46 of Set 4 | kavieng
# Processing Record 47 of Set 4 | saint-philippe
# Processing Record 48 of Set 4 | santa rosa
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 5 | nha trang
# Processing Record 2 of Set 5 | kodino
# Processing Record 3 of Set 5 | mount isa
# Processing Record 4 of Set 5 | comodoro rivadavia
# Processing Record 5 of Set 5 | nome
# Processing Record 6 of Set 5 | sur
# Processing Record 7 of Set 5 | topeka
# Processing Record 8 of Set 5 | gumdag
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 5 | prince rupert
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | ust-tsilma
# Processing Record 13 of Set 5 | potosi
# Processing Record 14 of Set 5 | hambantota
# Processing Record 15 of Set 5 | airai
# Processing Record 16 of Set 5 | khatanga
# Processing Record 17 of Set 5 | port elizabeth
# Processing Record 18 of Set 5 | constitucion
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | kaohsiung
# Processing Record 21 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 5 | camacari
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | grafton
# Processing Record 25 of Set 5 | luderitz
# Processing Record 26 of Set 5 | kharp
# Processing Record 27 of Set 5 | seddon
# Processing Record 28 of Set 5 | ko samui
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | bandarbeyla
# Processing Record 31 of Set 5 | yelizovo
# Processing Record 32 of Set 5 | jacqueville
# Processing Record 33 of Set 5 | gushikawa
# Processing Record 34 of Set 5 | isangel
# Processing Record 35 of Set 5 | pangnirtung
# Processing Record 36 of Set 5 | maniitsoq
# Processing Record 37 of Set 5 | north vanlaiphai
# Processing Record 38 of Set 5 | bathsheba
# Processing Record 39 of Set 5 | narsaq
# Processing Record 40 of Set 5 | cabra
# Processing Record 41 of Set 5 | taltal
# Processing Record 42 of Set 5 | tuy hoa
# Processing Record 43 of Set 5 | vizinga
# Processing Record 44 of Set 5 | margate
# Processing Record 45 of Set 5 | alexandria
# Processing Record 46 of Set 5 | miyazu
# Processing Record 47 of Set 5 | kloulklubed
# City not found. Skipping...
# Processing Record 48 of Set 5 | puerto suarez
# Processing Record 49 of Set 5 | katsuura
# Processing Record 50 of Set 5 | daugavpils
# Processing Record 1 of Set 6 | umm lajj
# Processing Record 2 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 6 | kropotkin
# Processing Record 4 of Set 6 | lanja
# Processing Record 5 of Set 6 | terney
# Processing Record 6 of Set 6 | hobyo
# Processing Record 7 of Set 6 | kutum
# Processing Record 8 of Set 6 | lorengau
# Processing Record 9 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 6 | lebu
# Processing Record 11 of Set 6 | kampong chhnang
# Processing Record 12 of Set 6 | yunyang
# Processing Record 13 of Set 6 | tapes
# Processing Record 14 of Set 6 | la palma
# Processing Record 15 of Set 6 | bacalar
# Processing Record 16 of Set 6 | broome
# Processing Record 17 of Set 6 | roches noires
# City not found. Skipping...
# Processing Record 18 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 19 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 6 | netrakona
# Processing Record 21 of Set 6 | yandyki
# Processing Record 22 of Set 6 | royan
# Processing Record 23 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 6 | dingle
# Processing Record 25 of Set 6 | vila franca do campo
# Processing Record 26 of Set 6 | norman wells
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | thinadhoo
# Processing Record 29 of Set 6 | sola
# Processing Record 30 of Set 6 | itaqui
# Processing Record 31 of Set 6 | kidal
# Processing Record 32 of Set 6 | varna
# Processing Record 33 of Set 6 | waipawa
# Processing Record 34 of Set 6 | mfou
# Processing Record 35 of Set 6 | milas
# Processing Record 36 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 37 of Set 6 | timra
# Processing Record 38 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 6 | namibe
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | magadan
# Processing Record 43 of Set 6 | muravlenko
# Processing Record 44 of Set 6 | beloha
# Processing Record 45 of Set 6 | sungurlu
# Processing Record 46 of Set 6 | moba
# Processing Record 47 of Set 6 | jutai
# Processing Record 48 of Set 6 | vila velha
# Processing Record 49 of Set 6 | san carlos de bariloche
# Processing Record 50 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | gonzales
# Processing Record 3 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 5 of Set 7 | sitka
# Processing Record 6 of Set 7 | vaitape
# Processing Record 7 of Set 7 | serenje
# Processing Record 8 of Set 7 | geraldton
# Processing Record 9 of Set 7 | labuhan
# Processing Record 10 of Set 7 | teya
# Processing Record 11 of Set 7 | brigantine
# Processing Record 12 of Set 7 | porto novo
# Processing Record 13 of Set 7 | leshukonskoye
# Processing Record 14 of Set 7 | chernyshevsk
# Processing Record 15 of Set 7 | mbuji-mayi
# Processing Record 16 of Set 7 | belyy yar
# Processing Record 17 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 18 of Set 7 | dekar
# Processing Record 19 of Set 7 | turner
# Processing Record 20 of Set 7 | unity
# Processing Record 21 of Set 7 | irituia
# Processing Record 22 of Set 7 | ternate
# Processing Record 23 of Set 7 | campbell river
# Processing Record 24 of Set 7 | saint george
# Processing Record 25 of Set 7 | hami
# Processing Record 26 of Set 7 | mar del plata
# Processing Record 27 of Set 7 | chicama
# Processing Record 28 of Set 7 | banjar
# Processing Record 29 of Set 7 | roald
# Processing Record 30 of Set 7 | birchis
# Processing Record 31 of Set 7 | concepcion del oro
# Processing Record 32 of Set 7 | kibala
# Processing Record 33 of Set 7 | pimentel
# Processing Record 34 of Set 7 | iralaya
# Processing Record 35 of Set 7 | palana
# Processing Record 36 of Set 7 | samsun
# Processing Record 37 of Set 7 | ulladulla
# Processing Record 38 of Set 7 | lar
# Processing Record 39 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 7 | husavik
# Processing Record 41 of Set 7 | stonewall
# Processing Record 42 of Set 7 | moose factory
# Processing Record 43 of Set 7 | pushkinskiye gory
# Processing Record 44 of Set 7 | lazaro cardenas
# Processing Record 45 of Set 7 | ilulissat
# Processing Record 46 of Set 7 | beitbridge
# Processing Record 47 of Set 7 | hirara
# Processing Record 48 of Set 7 | skibbereen
# Processing Record 49 of Set 7 | wanxian
# Processing Record 50 of Set 7 | ilebo
# Processing Record 1 of Set 8 | salalah
# Processing Record 2 of Set 8 | gorin
# Processing Record 3 of Set 8 | mazamari
# Processing Record 4 of Set 8 | gulu
# Processing Record 5 of Set 8 | brandon
# Processing Record 6 of Set 8 | bilma
# Processing Record 7 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 8 | moron
# Processing Record 9 of Set 8 | pirgos
# Processing Record 10 of Set 8 | scarborough
# Processing Record 11 of Set 8 | sao raimundo das mangabeiras
# Processing Record 12 of Set 8 | hay river
# Processing Record 13 of Set 8 | machico
# Processing Record 14 of Set 8 | morales
# Processing Record 15 of Set 8 | tateyama
# Processing Record 16 of Set 8 | evensk
# Processing Record 17 of Set 8 | tatarsk
# Processing Record 18 of Set 8 | klaksvik
# Processing Record 19 of Set 8 | tulcingo
# City not found. Skipping...
# Processing Record 20 of Set 8 | brae
# Processing Record 21 of Set 8 | saint-leu
# Processing Record 22 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 8 | gilazi
# City not found. Skipping...
# Processing Record 24 of Set 8 | beidao
# Processing Record 25 of Set 8 | chara
# Processing Record 26 of Set 8 | bulgan
# Processing Record 27 of Set 8 | nowa deba
# Processing Record 28 of Set 8 | chitose
# Processing Record 29 of Set 8 | dicabisagan
# Processing Record 30 of Set 8 | karratha
# Processing Record 31 of Set 8 | sigli
# Processing Record 32 of Set 8 | miandrivazo
# Processing Record 33 of Set 8 | crawfordsville
# Processing Record 34 of Set 8 | tilichiki
# Processing Record 35 of Set 8 | niquelandia
# Processing Record 36 of Set 8 | filingue
# Processing Record 37 of Set 8 | abha
# Processing Record 38 of Set 8 | gondanglegi
# Processing Record 39 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 8 | storslett
# Processing Record 41 of Set 8 | pandamatenga
# Processing Record 42 of Set 8 | nuevitas
# Processing Record 43 of Set 8 | gornoye loo
# Processing Record 44 of Set 8 | ketchikan
# Processing Record 45 of Set 8 | sangmelima
# Processing Record 46 of Set 8 | zhigansk
# Processing Record 47 of Set 8 | raga
# Processing Record 48 of Set 8 | synya
# Processing Record 49 of Set 8 | gewane
# Processing Record 50 of Set 8 | kisanga
# Processing Record 1 of Set 9 | caucaia
# Processing Record 2 of Set 9 | cherskiy
# Processing Record 3 of Set 9 | rawson
# Processing Record 4 of Set 9 | tibiri
# Processing Record 5 of Set 9 | poronaysk
# Processing Record 6 of Set 9 | lusambo
# Processing Record 7 of Set 9 | dakar
# Processing Record 8 of Set 9 | harper
# Processing Record 9 of Set 9 | asau
# Processing Record 10 of Set 9 | osa
# Processing Record 11 of Set 9 | chebarkul
# Processing Record 12 of Set 9 | bukachacha
# Processing Record 13 of Set 9 | grand gaube
# Processing Record 14 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 9 | tricase
# Processing Record 16 of Set 9 | la ronge
# Processing Record 17 of Set 9 | egvekinot
# Processing Record 18 of Set 9 | vanavara
# Processing Record 19 of Set 9 | marshall
# Processing Record 20 of Set 9 | kolimvari
# City not found. Skipping...
# Processing Record 21 of Set 9 | samarai
# Processing Record 22 of Set 9 | san quintin
# Processing Record 23 of Set 9 | atar
# Processing Record 24 of Set 9 | dotnuva
# Processing Record 25 of Set 9 | nkayi
# Processing Record 26 of Set 9 | kurilsk
# Processing Record 27 of Set 9 | tabuk
# Processing Record 28 of Set 9 | tutoia
# Processing Record 29 of Set 9 | lakes entrance
# Processing Record 30 of Set 9 | gladstone
# Processing Record 31 of Set 9 | dandong
# Processing Record 32 of Set 9 | hualmay
# Processing Record 33 of Set 9 | vestmannaeyjar
# Processing Record 34 of Set 9 | crateus
# Processing Record 35 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 9 | burica
# City not found. Skipping...
# Processing Record 37 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 38 of Set 9 | port hardy
# Processing Record 39 of Set 9 | fairbanks
# Processing Record 40 of Set 9 | cowra
# Processing Record 41 of Set 9 | yumen
# Processing Record 42 of Set 9 | george town
# Processing Record 43 of Set 9 | srednekolymsk
# Processing Record 44 of Set 9 | keokuk
# Processing Record 45 of Set 9 | gold coast
# Processing Record 46 of Set 9 | iqaluit
# Processing Record 47 of Set 9 | oranjemund
# Processing Record 48 of Set 9 | manavgat
# Processing Record 49 of Set 9 | orlik
# Processing Record 50 of Set 9 | codrington
# Processing Record 1 of Set 10 | caravelas
# Processing Record 2 of Set 10 | teofilo otoni
# Processing Record 3 of Set 10 | mangit
# Processing Record 4 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 10 | bossangoa
# Processing Record 6 of Set 10 | haines junction
# Processing Record 7 of Set 10 | trollhattan
# Processing Record 8 of Set 10 | coolum beach
# Processing Record 9 of Set 10 | mukhen
# Processing Record 10 of Set 10 | mersing
# Processing Record 11 of Set 10 | laviana
# Processing Record 12 of Set 10 | tamandare
# Processing Record 13 of Set 10 | talnakh
# Processing Record 14 of Set 10 | kindia
# Processing Record 15 of Set 10 | viedma
# Processing Record 16 of Set 10 | gorontalo
# Processing Record 17 of Set 10 | kadnikov
# Processing Record 18 of Set 10 | shimoda
# Processing Record 19 of Set 10 | oktyabrskiy
# Processing Record 20 of Set 10 | waghai
# Processing Record 21 of Set 10 | bilibino
# Processing Record 22 of Set 10 | hervey bay
# Processing Record 23 of Set 10 | lavrentiya
# Processing Record 24 of Set 10 | alice springs
# Processing Record 25 of Set 10 | ponca city
# Processing Record 26 of Set 10 | hofn
# Processing Record 27 of Set 10 | ligayan
# Processing Record 28 of Set 10 | kokstad
# Processing Record 29 of Set 10 | berlevag
# Processing Record 30 of Set 10 | kyzyl-suu
# Processing Record 31 of Set 10 | pemangkat
# Processing Record 32 of Set 10 | bardiyah
# Processing Record 33 of Set 10 | sooke
# Processing Record 34 of Set 10 | porto velho
# Processing Record 35 of Set 10 | ye
# City not found. Skipping...
# Processing Record 36 of Set 10 | izberbash
# Processing Record 37 of Set 10 | mezen
# Processing Record 38 of Set 10 | port said
# Processing Record 39 of Set 10 | kailua
# Processing Record 40 of Set 10 | kautokeino
# Processing Record 41 of Set 10 | santa cruz
# Processing Record 42 of Set 10 | itarema
# Processing Record 43 of Set 10 | ayr
# Processing Record 44 of Set 10 | lata
# Processing Record 45 of Set 10 | ginir
# Processing Record 46 of Set 10 | solnechnyy
# Processing Record 47 of Set 10 | tabas
# Processing Record 48 of Set 10 | krasnoselkup
# Processing Record 49 of Set 10 | olafsvik
# Processing Record 50 of Set 10 | jega
# Processing Record 1 of Set 11 | canmore
# Processing Record 2 of Set 11 | chernyshevskiy
# Processing Record 3 of Set 11 | qianan
# Processing Record 4 of Set 11 | bubaque
# Processing Record 5 of Set 11 | farafangana
# Processing Record 6 of Set 11 | dawson creek
# Processing Record 7 of Set 11 | kaspiysk
# Processing Record 8 of Set 11 | nivala
# Processing Record 9 of Set 11 | grootfontein
# Processing Record 10 of Set 11 | coquimbo
# Processing Record 11 of Set 11 | ayan
# Processing Record 12 of Set 11 | teahupoo
# Processing Record 13 of Set 11 | makakilo city
# Processing Record 14 of Set 11 | smithers
# Processing Record 15 of Set 11 | krasnokamensk
# Processing Record 16 of Set 11 | new glasgow
# Processing Record 17 of Set 11 | hasaki
# Processing Record 18 of Set 11 | kaka
# Processing Record 19 of Set 11 | muisne
# Processing Record 20 of Set 11 | kulhudhuffushi
# Processing Record 21 of Set 11 | richards bay
# Processing Record 22 of Set 11 | aksarka
# Processing Record 23 of Set 11 | gandu
# Processing Record 24 of Set 11 | gamba
# Processing Record 25 of Set 11 | kungurtug
# Processing Record 26 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 27 of Set 11 | shingu
# Processing Record 28 of Set 11 | makaha
# Processing Record 29 of Set 11 | manaure
# Processing Record 30 of Set 11 | cururupu
# Processing Record 31 of Set 11 | palu
# Processing Record 32 of Set 11 | tual
# Processing Record 33 of Set 11 | neuquen
# Processing Record 34 of Set 11 | podor
# Processing Record 35 of Set 11 | harindanga
# Processing Record 36 of Set 11 | necochea
# Processing Record 37 of Set 11 | kijang
# Processing Record 38 of Set 11 | fallon
# Processing Record 39 of Set 11 | gulbarga
# Processing Record 40 of Set 11 | tabou
# Processing Record 41 of Set 11 | teguldet
# Processing Record 42 of Set 11 | werda
# Processing Record 43 of Set 11 | yuzhnyy-kospashskiy
# Processing Record 44 of Set 11 | cienfuegos
# Processing Record 45 of Set 11 | japura
# Processing Record 46 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 11 | podgornoye
# Processing Record 48 of Set 11 | half moon bay
# Processing Record 49 of Set 11 | tomari
# Processing Record 50 of Set 11 | fukuma
# Processing Record 1 of Set 12 | kirakira
# Processing Record 2 of Set 12 | paamiut
# Processing Record 3 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 4 of Set 12 | tocopilla
# Processing Record 5 of Set 12 | camocim
# Processing Record 6 of Set 12 | batagay-alyta
# Processing Record 7 of Set 12 | vzmorye
# Processing Record 8 of Set 12 | moranbah
# Processing Record 9 of Set 12 | xichang
# Processing Record 10 of Set 12 | san luis
# Processing Record 11 of Set 12 | boyolangu
# Processing Record 12 of Set 12 | kjollefjord
# Processing Record 13 of Set 12 | gat
# Processing Record 14 of Set 12 | charters towers
# Processing Record 15 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 16 of Set 12 | nouakchott
# Processing Record 17 of Set 12 | jumla
# Processing Record 18 of Set 12 | nikolayevsk-na-amure
# Processing Record 19 of Set 12 | eyl
# Processing Record 20 of Set 12 | galle
# Processing Record 21 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 12 | nabire
# Processing Record 24 of Set 12 | san rafael
# Processing Record 25 of Set 12 | bar harbor
# Processing Record 26 of Set 12 | sinnamary
# Processing Record 27 of Set 12 | cukai
# Processing Record 28 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 30 of Set 12 | palmer
# Processing Record 31 of Set 12 | kupino
# Processing Record 32 of Set 12 | varzea alegre
# Processing Record 33 of Set 12 | shirokiy
# Processing Record 34 of Set 12 | la gomera
# Processing Record 35 of Set 12 | katsina
# Processing Record 36 of Set 12 | koboko
# Processing Record 37 of Set 12 | tazovskiy
# Processing Record 38 of Set 12 | austin
# Processing Record 39 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 12 | kaputa
# Processing Record 41 of Set 12 | inhambane
# Processing Record 42 of Set 12 | leh
# Processing Record 43 of Set 12 | arman
# Processing Record 44 of Set 12 | virginia beach
# Processing Record 45 of Set 12 | sweetwater
# Processing Record 46 of Set 12 | kimbe
# Processing Record 47 of Set 12 | beruwala
# Processing Record 48 of Set 12 | bagamoyo
# Processing Record 49 of Set 12 | havre-saint-pierre
# Processing Record 50 of Set 12 | touba
# Processing Record 1 of Set 13 | veraval
# Processing Record 2 of Set 13 | ust-maya
# Processing Record 3 of Set 13 | srikakulam
# Processing Record 4 of Set 13 | te anau
# Processing Record 5 of Set 13 | gannan
# Processing Record 6 of Set 13 | cerritos
# Processing Record 7 of Set 13 | melfort
# Processing Record 8 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 9 of Set 13 | kon tum
# Processing Record 10 of Set 13 | melfi
# Processing Record 11 of Set 13 | saint-augustin
# Processing Record 12 of Set 13 | gornopravdinsk
# Processing Record 13 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 13 | eyrarbakki
# Processing Record 15 of Set 13 | areni
# Processing Record 16 of Set 13 | matagalpa
# Processing Record 17 of Set 13 | olinda
# Processing Record 18 of Set 13 | auki
# Processing Record 19 of Set 13 | salmas
# Processing Record 20 of Set 13 | edremit
# Processing Record 21 of Set 13 | tumen
# Processing Record 22 of Set 13 | soc trang
# Processing Record 23 of Set 13 | ossora
# Processing Record 24 of Set 13 | mahendranagar
# Processing Record 25 of Set 13 | bansi
# Processing Record 26 of Set 13 | cradock
# Processing Record 27 of Set 13 | jiuquan
# Processing Record 28 of Set 13 | carahue
# Processing Record 29 of Set 13 | narbonne
# Processing Record 30 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 13 | walvis bay
# Processing Record 32 of Set 13 | belyy
# Processing Record 33 of Set 13 | rio grande
# Processing Record 34 of Set 13 | revelstoke
# Processing Record 35 of Set 13 | hovd
# Processing Record 36 of Set 13 | rio gallegos
# Processing Record 37 of Set 13 | abnub
# Processing Record 38 of Set 13 | taunggyi
# Processing Record 39 of Set 13 | vysokogornyy
# Processing Record 40 of Set 13 | cortez
# Processing Record 41 of Set 13 | lufilufi
# Processing Record 42 of Set 13 | mizdah
# Processing Record 43 of Set 13 | vila
# Processing Record 44 of Set 13 | liverpool
# Processing Record 45 of Set 13 | niamtougou
# Processing Record 46 of Set 13 | belmonte
# Processing Record 47 of Set 13 | tiarei
# Processing Record 48 of Set 13 | luwuk
# Processing Record 49 of Set 13 | poum
# Processing Record 50 of Set 13 | garowe
# Processing Record 1 of Set 14 | angoche
# Processing Record 2 of Set 14 | puerto leguizamo
# Processing Record 3 of Set 14 | yakeshi
# Processing Record 4 of Set 14 | opuwo
# Processing Record 5 of Set 14 | okakarara
# Processing Record 6 of Set 14 | ranong
# Processing Record 7 of Set 14 | kazerun
# Processing Record 8 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 9 of Set 14 | kenai
# Processing Record 10 of Set 14 | maryville
# Processing Record 11 of Set 14 | trujillo
# Processing Record 12 of Set 14 | tigil
# Processing Record 13 of Set 14 | kamenka
# Processing Record 14 of Set 14 | sikeston
# Processing Record 15 of Set 14 | baracoa
# Processing Record 16 of Set 14 | zhumadian
# Processing Record 17 of Set 14 | balikpapan
# Processing Record 18 of Set 14 | san
# Processing Record 19 of Set 14 | san martin
# Processing Record 20 of Set 14 | tezu
# Processing Record 21 of Set 14 | longhua
# Processing Record 22 of Set 14 | tungor
# Processing Record 23 of Set 14 | bestobe
# Processing Record 24 of Set 14 | tsogni
# Processing Record 25 of Set 14 | avera
# Processing Record 26 of Set 14 | daru
# Processing Record 27 of Set 14 | muroto
# Processing Record 28 of Set 14 | alofi
# Processing Record 29 of Set 14 | panzhihua
# Processing Record 30 of Set 14 | pullman
# Processing Record 31 of Set 14 | maumere
# Processing Record 32 of Set 14 | kokoda
# Processing Record 33 of Set 14 | kisangani
# Processing Record 34 of Set 14 | gwadar
# Processing Record 35 of Set 14 | portland
# Processing Record 36 of Set 14 | mugango
# Processing Record 37 of Set 14 | teguise
# Processing Record 38 of Set 14 | colon
# Processing Record 39 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 14 | jinan
# Processing Record 41 of Set 14 | garissa
# Processing Record 42 of Set 14 | kamyshin
# Processing Record 43 of Set 14 | sterling
# Processing Record 44 of Set 14 | rybnoye
# Processing Record 45 of Set 14 | ixtapa
# Processing Record 46 of Set 14 | bonthe
# Processing Record 47 of Set 14 | la esperanza
# Processing Record 48 of Set 14 | san pedro
# Processing Record 49 of Set 14 | guerrero negro
# Processing Record 50 of Set 14 | champerico
# Processing Record 1 of Set 15 | martapura
# Processing Record 2 of Set 15 | wad madani
# Processing Record 3 of Set 15 | kribi
# Processing Record 4 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 15 | gao
# Processing Record 6 of Set 15 | calvinia
# Processing Record 7 of Set 15 | coihaique
# Processing Record 8 of Set 15 | sept-iles
# Processing Record 9 of Set 15 | conceicao da barra
# Processing Record 10 of Set 15 | nikolo-pavlovskoye
# Processing Record 11 of Set 15 | kasempa
# Processing Record 12 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 15 | segou
# Processing Record 14 of Set 15 | mutum
# Processing Record 15 of Set 15 | russellville
# Processing Record 16 of Set 15 | along
# Processing Record 17 of Set 15 | ust-nera
# Processing Record 18 of Set 15 | moanda
# Processing Record 19 of Set 15 | kaliwungu
# Processing Record 20 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 21 of Set 15 | boguchany
# Processing Record 22 of Set 15 | ust-ishim
# Processing Record 23 of Set 15 | anloga
# Processing Record 24 of Set 15 | sao jose da coroa grande
# Processing Record 25 of Set 15 | okha
# Processing Record 26 of Set 15 | alekseyevka
# Processing Record 27 of Set 15 | amga
# Processing Record 28 of Set 15 | chippewa falls
# Processing Record 29 of Set 15 | uige
# Processing Record 30 of Set 15 | inuvik
# Processing Record 31 of Set 15 | verkhoyansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 666

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Monrovia   6.3005  -10.7969     75.25        75          70
# 1        Lompoc  34.6391 -120.4579     87.01        72           0
# 2    Kuvshinovo  57.0295   34.1725     48.45        88          18
# 3        Dikson  73.5069   80.5464     41.36        94         100
# 4  Kruisfontein -34.0033   24.7314     49.46        81          88
# 5       Rikitea -23.1203 -134.9692     72.70        75           5
# 6       Ushuaia -54.8000  -68.3000     44.26        61          40
# 7          Mayo  38.8876  -76.5119     84.15        73           0
# 8        Barrow  71.2906 -156.7887     35.62        87         100
# 9  Punta Arenas -53.1500  -70.9167     41.11        70           0
#
#    Wind Speed Current Description Country                 Date
# 0        6.73       broken clouds      LR  2022-07-31 00:43:10
# 1       13.80           clear sky      US  2022-07-31 00:43:10
# 2        3.40          few clouds      RU  2022-07-31 00:43:10
# 3        9.69     overcast clouds      RU  2022-07-31 00:43:10
# 4       12.64          light rain      ZA  2022-07-31 00:38:36
# 5       15.61           clear sky      PF  2022-07-31 00:35:58
# 6       13.80    scattered clouds      AR  2022-07-31 00:38:43
# 7        3.44           clear sky      US  2022-07-31 00:38:38
# 8        6.91     overcast clouds      US  2022-07-31 00:43:16
# 9       21.85           clear sky      CL  2022-07-31 00:38:33

# %%
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Monrovia      LR   6.3005  -10.7969     75.25        75          70
# 1        Lompoc      US  34.6391 -120.4579     87.01        72           0
# 2    Kuvshinovo      RU  57.0295   34.1725     48.45        88          18
# 3        Dikson      RU  73.5069   80.5464     41.36        94         100
# 4  Kruisfontein      ZA -34.0033   24.7314     49.46        81          88
# 5       Rikitea      PF -23.1203 -134.9692     72.70        75           5
# 6       Ushuaia      AR -54.8000  -68.3000     44.26        61          40
# 7          Mayo      US  38.8876  -76.5119     84.15        73           0
# 8        Barrow      US  71.2906 -156.7887     35.62        87         100
# 9  Punta Arenas      CL -53.1500  -70.9167     41.11        70           0
#
#    Wind Speed Current Description
# 0        6.73       broken clouds
# 1       13.80           clear sky
# 2        3.40          few clouds
# 3        9.69     overcast clouds
# 4       12.64          light rain
# 5       15.61           clear sky
# 6       13.80    scattered clouds
# 7        3.44           clear sky
# 8        6.91     overcast clouds
# 9       21.85           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
